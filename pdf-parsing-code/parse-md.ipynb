# %%
## Import necessary packages
import pandas as pd
import numpy as np
import tkinter as tk
import PyPDF2 
import tabula
import tkinter
import camelot
import ghostscript
import re
import os
import csv
import urllib
import io
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Maryland
#
# ### Comprehensive PPL

# %%
# get the full table
md_comp = camelot.read_pdf("https://mde.maryland.gov/programs/water/WQFA/Documents/FFY22%20SFY24%20Final%20DW%20PPL.pdf", 
                           pages='1-9', flavor='lattice')
print(len(md_comp))
# Out:
# 9

# %%
# create list to append into
list_of_dfs = []

for i in range(len(md_comp)):
    # read in each page
    md = md_comp[i].df.iloc[1:,].copy()

    ## split the 0 column (Rank/Points) by line breaks
    # regex looks for a number greedily, then any amount of whtie space, then another number greedily
    md[['Rank', 'Points']] = md[0].str.extract(r'(\d+)\s*(\d+)')


    ##split the 1 column (Project Title / Number / Population) by the opening parantheses before the pwsid
    md[['ProjectTitle', 'PWSID.Pop.ProjectNumber']] = md[1].str.split("\n\(MD", expand=True)

    # split PWSID from Population and ProjectNumber by the other parentheses
    md[['PWSID', 'Pop.ProjectNumber']] = md["PWSID.Pop.ProjectNumber"].str.split("\)\n", expand=True)
    # add MD back to the PWSID after using it to split earlier columns to avoid issues with multiple splits
    md['PWSID'] = "MD" + md['PWSID']

    # remove population pretense
    md['Pop.ProjectNumber'] = md['Pop.ProjectNumber'].str.replace("Ben.Pop=\n", "")

    # split population and project number
    md[['Population', 'ProjectNumber']] = md['Pop.ProjectNumber'].str.split("\n", expand=True)

    #replace line breaks with spaces in ProjectTitle
    md['ProjectTitle'] = md['ProjectTitle'].str.replace("\n", " ") 


    ## column 2 only needs line breaks replace with spaces
    md['ProjectDescription'] = md[2].str.replace("\n", " ") 


    ## column 3 (Applicant Name / County) split by system size and characters around it
    md[["Name.Borrower", "Size.County"]] = md[3].str.split("\nSystem Size =\n", expand=True, n=2)

    # split by breaks only once because names are only one line but borrower can be two, replace remaining line breaks with space
    md[["Name", "Borrower"]] = md['Name.Borrower'].str.split("\n", n=1, expand=True)
    md['Borrower'] = md['Borrower'].str.replace("\n", " ")

    # split by line break
    md[['Size', 'County']] = md['Size.County'].str.split("\n", expand=True)


    ## column 4 only needs to be split by line breaks, but this data is not currently used in the dashboard
    # md[["LegDistrict", "CongDistrict"]] = md[4].str.split("\n", n=1, expand=True)


    ## column 5 needs to have Disadvantaged extracted from it, the rest is not currently used in the dashboard
    md['Disadvantaged'] = np.where(md[5].str.contains("DISADV."), "Yes", "No")

    ## column 6 can be ignored because we currently use no dates in the dashboard

    ## column 7 splits by line break between Total Cost and a variable we won't use for dashboard purposes
    md[['TotalCost', 'Details']] = md[7].str.split("\n", n=1, expand=True)


    ## column 8 - in each row, the numbers are the same, so just keep the first, similar to column 7
    md[['RequestedFunding', 'LoanDetails']] = md[8].str.split("\n", n=1, expand=True)

    # drop in-process columns
    md.drop(columns=[0,1,2,3,4,5,6,7,8,'Size', 'Name.Borrower', 'Size.County', 'Details','LoanDetails', 
            'PWSID.Pop.ProjectNumber', 'Pop.ProjectNumber'], inplace=True)

    # append to list    
    list_of_dfs.append(md)
    
# concat with common column names    
md_output = pd.concat(list_of_dfs)

# %%
md_output.reset_index(drop=True, inplace=True)
# drop total rows
md_output = md_output.iloc[:-2,]

# %%
md_output
# Out:
#    Rank Points                                       ProjectTitle      PWSID  \
# 0     1    117           NEW WINTERS RUN WATER TREATMENT FACILITY  MD0120003
# 40   41     37  WC-1319 KESWICK ROAD, WEST 36TH STREET & YORK ...  MD300002
# 41   42     35  BEACHES WATER CO-OP (BWC) REDUCING LEAD IN DRI...  MD
# 42   43     25                       MARTINGHAM SMART WATER METER  MD0200004
#
#     Population ProjectNumber  \
# 0       15,500        DW0016
# 1        4,075        DW0004
# 2           60        DW0017
# 3        6,218        DW0025
# 4       32,673        DW0015
# 5           93        DW0021
# 6        2,150        DW0002
# 7        2,770        DW0018
# 8        6,925        DW0019
# 9       25,580        DW0034
# 10         573        DW0042
# 11         610        DW0041
# 12         920        DW0030
# 13       7,528        DW0036
# 14         388        DW0040
# 15   1,800,000        DW0007
# 16  Ben.Pop= ?        DW0022
# 17       2,363        DW0020
# 18       2,448        DW0038
# 19     108,600        DW0033
# 20       5,045        DW0003
# 21       9,200        DW0031
# 22       3,275        DW0029
# 23       4,500        DW0027
# 24          95        DW0026
# 25         163        DW0014
# 26       1,500        DW0032
# 27       1,325        DW0028
# 28   1,800,000        DW0006
# 29  Ben.Pop= ?        DW0024
# 30     108,600        DW0035
# 31     600,000        DW0009
# 32     600,000        DW0011
# 33     600,000        DW0013
# 34   1,800,000        DW0005
# 35  Ben.Pop= ?        DW0023
# 36       4,478        DW0037
# 37   2,100,000        DW0043
# 38       1,585        DW0008
# 39       1,585        DW0010
# 40       1,628        DW0012
# 41       2,010        DW0039
# 42         770        DW0001
#
#                                    ProjectDescription  \
# 0   PROBLEM: 70-YEAR OLD PLANT SITUATED IN 100-YR ...
# 1   PROBLEM: HIGH RUST AND CONTAMINANTS IN WATER S...
# 2   PROBLEM: CONTAMINATED DRINKING WATER SOURCE SE...
# 3   PROBLEM: AGING AND FAILING WATER MAIN REQUIRES...
# 4   PROBLEM: PROVIDE A RELIABLE SUPPLEMENTAL AND B...
# 5   PROBLEM: SOURCE DRINKING WATER CONTAMINATED WI...
# 6   PROBLEM: NO BACKUP POWER TO LARGEST PRODUCING ...
# 7   PROBLEM: WATER PRESSURE COMPLIANCE AND RESOLVE...
# 8   PROBLEM: WATER PRESSURE COMPLIANCE AND RESOLVE...
# 9   PROBLEM: TANK HAS EXCEEDED USEFUL LIFE AND DEV...
# 10  PROBLEM: BARE CAST IRON MAINS WITH TUBERCULATI...
# 11  PROBLEM: BARE CAST IRON MAINS WITH TUBERCULATI...
# 12  PROBLEM: AREA NOT SERVED BY PUBLIC WATER EXPER...
# 13  PROBLEM: 1.5M GAL DRINKING WATER RESERVOIR LEA...
# 14  PROBLEM: BARE CAST IRON MAINS WITH TUBERCULATI...
# 15  PROBLEM: PUMP STATION FOR ASHBURTON RESERVOIR ...
# 16  PROBLEM: PUMP STATION FOR ASHBURTON RESERVOIR ...
# 17  PROBLEM: FREQUENT BREAKS - 85-YEAR-OLD WATER L...
# 18  PROBLEM: FAILING WATER MAINS OVER 100 YR OLD. ...
# 19  PROBLEM: DETERIORATED 90+ YEAR OLD TRANSMISSIO...
# 20  PROBLEM: WELL #2 IS 58 YEARS OLD AND HAS OUTLI...
# 21  PROBLEM: GRANTSVILLE WATER LEAKS, SERVICE SPRI...
# 22  PROBLEM: DETERIORATING PIPES LEAKING >40% INTO...
# 23  PROBLEM: DAM INSPECTION CLASSIFIED A HIGH HAZA...
# 24  PROBLEM: 50+ YR OLD WATER LINES CANNOT BE MAIN...
# 25  PROBLEM: AGING AND INADEQUATE SUPPLY LINES THA...
# 26  PROBLEM: CURRENT WATER METERS AND CRADLES CONT...
# 27  PROBLEM: CAST IRON WATER MAINS, MOST OVER 120 ...
# 28  PROBLEM: AGING PUMPING STATION NECESSARY PART ...
# 29  PROBLEM: AGING PUMPING STATION NECESSARY PART ...
# 30  PROBLEM: WTP CANNOT RECEIVE CHEMICAL DELIVERIE...
# 31  PROBLEM: DETERIORATION OF UNLINED CAST IRON PI...
# 32  PROBLEM: DETERIORATION OF UNLINED CAST IRON PI...
# 33  PROBLEM: DETERIORATION OF UNLINED CAST IRON PI...
# 34  PROBLEM: AGING PUMPING STATION NECESSARY PART ...
# 35  PROBLEM: AGING PUMPING STATION NECESSARY PART ...
# 36  PROBLEM: LACK OF WATER PRESSURE, ESPECIALLY IN...
# 37  PROBLEM: IMPROVE EFFICIENCY OF OPERATIONS, FLO...
# 38  PROBLEM: DETERIORATION OF UNLINED CAST IRON PI...
# 39  PROBLEM: DETERIORATION OF UNLINED CAST IRON PI...
# 40  PROBLEM: DETERIORATION OF UNLINED CAST IRON PI...
# 41  PROBLEM: AGED PIPING AND FITTINGS WITH LEAD CO...
# 42  PROBLEM: REPLACE OLD, INACCURATE DIFFICULT-TO-...
#
#                         Name                                         Borrower  \
# 0             BARRY L. SUITS                          MARYLAND AMERICAN WATER
# 1               LINDA MCNEIL                                    POCOMOKE CITY
# 2         RODNEY WINEBRENNER                                 FREDERICK COUNTY
# 3             DAVID S. WENDT                         LAVALE SANITARY DISTRICT
# 4      JEFFREY D. CASTONGUAY                BOARD OF CARROLL CO COMMISSIONERS
# 5         RODNEY WINEBRENNER                                 FREDERICK COUNTY
# 6               RICK POLLITT                                TOWN OF SNOW HILL
# 7              CATHY WILLETS                               TOWN OF EMMITSBURG
# 8              CATHY WILLETS                               TOWN OF EMMITSBURG
# 9               WILLIAM LUHN       CITY OF HAGERSTOWN -- UTILITIES DEPARTMENT
# 10  CAVILLE STANBURY-WOOLERY          WASHINGTON SUBURBAN SANITARY COMMISSION
# 11  CAVILLE STANBURY-WOOLERY          WASHINGTON SUBURBAN SANITARY COMMISSION
# 12               ROBIN JONES                              TOWN OF GRANTSVILLE
# 13             PAUL MANTELLO                                TOWN OF BOONSBORO
# 14  CAVILLE STANBURY-WOOLERY          WASHINGTON SUBURBAN SANITARY COMMISSION
# 15               AARON MOORE              MAYOR AND CITY COUNCIL OF BALTIMORE
# 16             ROBERT BURROS                       BALTIMORE COUNTY, MARYLAND
# 17                DAVID DUNN                MAYOR & COUNCIL CITY OF BRUNSWICK
# 18           AARON LATTANZIA                              TOWN OF WESTERNPORT
# 19              WILLIAM LUHN       CITY OF HAGERSTOWN -- UTILITIES DEPARTMENT
# 20            JEFF FLEETWOOD                                   TOWN OF BERLIN
# 21               ROBIN JONES                              TOWN OF GRANTSVILLE
# 22                BOBBY WITT                 GARRETT COUNTY SANITARY DISTRICT
# 23              TYLER RAYNER                               TOWN OF LONACONING
# 24                JIM WEBBER                    ALLEGANY COUNTY COMMISSIONERS
# 25          GARY P. DYE, JR.                              TOWN OF NEW WINDSOR
# 26             MARK BRADSHAW  WASHINGTON COUNTY BOARD OF COUNTY COMMISSIONERS
# 27              ROBERT SMITH             MAYOR AND CITY COUNCIL OF CUMBERLAND
# 28               AARON MOORE              MAYOR AND CITY COUNCIL OF BALTIMORE
# 29             ROBERT BURROS                       BALTIMORE COUNTY, MARYLAND
# 30              WILLIAM LUHN       CITY OF HAGERSTOWN -- UTILITIES DEPARTMENT
# 31               AARON MOORE              MAYOR AND CITY COUNCIL OF BALTIMORE
# 32               AARON MOORE              MAYOR AND CITY COUNCIL OF BALTIMORE
# 33               AARON MOORE              MAYOR AND CITY COUNCIL OF BALTIMORE
# 34               AARON MOORE              MAYOR AND CITY COUNCIL OF BALTIMORE
# 35             ROBERT BURROS                       BALTIMORE COUNTY, MARYLAND
# 36               CHAD ROONEY                               TOWN OF SMITHSBURG
# 37            BRIAN HALLORAN          WASHINGTON SUBURBAN SANITARY COMMISSION
# 38               AARON MOORE              MAYOR AND CITY COUNCIL OF BALTIMORE
# 39               AARON MOORE              MAYOR AND CITY COUNCIL OF BALTIMORE
# 40               AARON MOORE              MAYOR AND CITY COUNCIL OF BALTIMORE
# 41            DENNIS DIBELLO                              BEACHES WATER CO-OP
# 42             JAY T. FRENCH                 MARTINGHAM UTILITIES COOPERATIVE
#
#                County Disadvantaged    TotalCost RequestedFunding
# 0      Harford County            No   18,000,000        9,000,000
# 1    Worcester County           Yes    2,256,700          843,923
# 2    Frederick County            No      121,178          121,178
# 3     Allegany County           Yes    5,072,800        4,602,800
# 4      Carroll County            No    4,030,000        1,000,000
# 5    Frederick County            No      632,772          632,772
# 6    Worcester County           Yes      223,064          218,064
# 7    Frederick County            No    1,170,552        1,145,552
# 8    Frederick County            No    1,135,000        1,110,000
# 9   Washington County           Yes    4,600,000        4,000,000
# 10               WSSC           Yes    2,461,000        2,461,000
# 11               WSSC           Yes    3,400,000        3,400,000
# 12     Garrett County           Yes    8,064,990        8,035,000
# 13  Washington County            No    4,100,000        1,000,000
# 14               WSSC            No    4,416,000        4,416,000
# 15     Baltimore City           Yes   67,964,878       27,818,640
# 16   Baltimore County            No            0       31,943,493
# 17   Frederick County            No    5,000,000        4,200,000
# 18    Allegany County           Yes   18,192,000       18,162,000
# 19  Washington County           Yes   17,250,000       15,000,000
# 20   Worcester County           Yes      160,000          130,000
# 21     Garrett County           Yes    9,182,990        9,153,000
# 22     Garrett County           Yes    1,602,274        1,587,274
# 23    Allegany County           Yes    9,904,840        9,904,840
# 24    Allegany County           Yes    1,000,000        1,000,000
# 25     Carroll County            No    4,277,748        1,960,000
# 26  Washington County            No    1,000,000          700,000
# 27    Allegany County           Yes    4,114,000        4,114,000
# 28     Baltimore City           Yes   63,352,661       17,654,544
# 29   Baltimore County            No            0       29,775,751
# 30  Washington County           Yes    1,150,000        1,000,000
# 31     Baltimore City           Yes   10,484,177       10,484,177
# 32     Baltimore City           Yes   24,232,901       24,232,901
# 33     Baltimore City           Yes   14,327,306       14,327,306
# 34     Baltimore City           Yes   72,118,232       33,949,188
# 35   Baltimore County            No            0       28,847,293
# 36  Washington County            No    1,653,123        1,002,100
# 37               WSSC            No   42,838,000       21,414,000
# 38     Baltimore City           Yes  119,423,360       11,942,336
# 39     Baltimore City           Yes   16,002,796       16,002,796
# 40     Baltimore City           Yes   13,900,478       13,900,478
# 41     Calvert County            No    1,500,000        1,500,000
# 42      Talbot County           Yes      141,378          141,378

# %%
md_output.to_csv("../data/year1/csv/20-Maryland_ComprehensivePPL.csv", index=False)
